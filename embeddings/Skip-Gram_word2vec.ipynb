# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)

freqs = { word: count/total_count for word, count in word_counts.items() }
probability = { word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts }

train_words = [word for word in int_words if probability[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1: stop + 1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="input")
    labels = tf.placeholder(tf.int32, shape=[None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, 
                                      softmax_b, 
                                      labels, 
                                      embed, 
                                      n_sampled, 
                                      n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.8881 0.4337 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.7184 0.4433 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.5321 0.4340 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.3492 0.4267 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.2044 0.4316 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.0975 0.4320 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.0093 0.4488 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.9184 0.4266 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.6998 0.4203 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.5584 0.4194 sec/batch
# Nearest to called: nights, passageway, indiscernibles, faire, flanking, hartsfield, zoramites, turvy,
# Nearest to so: murdered, intracranial, racquetball, clitoridectomy, eng, amazona, endocytosis, inked,
# Nearest to can: neg, o, thawing, abingdon, brassy, forsyth, mandated, betty,
# Nearest to zero: example, shahade, staircase, endorsements, asdb, inman, instinct, relentless,
# Nearest to as: business, titanium, wakefulness, bez, worsen, louisiane, baryons, ekaggata,
# Nearest to years: semigroup, housewife, disingenuous, hostname, somehow, dolchsto, memorize, incommunicado,
# Nearest to have: owyn, absolutes, awaiting, loco, ministries, glows, decrying, rivi,
# Nearest to new: risen, electroshock, stocking, inflation, sigur, ratzenberger, bowls, palacio,
# Nearest to issue: brad, handwriting, mescaline, darling, kober, absurd, johor, kpa,
# Nearest to assembly: pliocene, bias, inflation, ajmer, asymptotically, congreve, thabit, simulant,
# Nearest to paris: helms, luxuries, solent, outskirts, bhojpuri, shaken, arbuckle, serra,
# Nearest to recorded: merrill, pepe, release, founding, brightness, sumitomo, hplc, bluerhinos,
# Nearest to event: recap, enormously, tefan, analysis, childe, hath, blackbody, hydras,
# Nearest to frac: woolworth, classifies, jeux, monotonicity, gie, potassium, savanna, graf,
# Nearest to primarily: mordor, supposing, yugoslavian, macroeconomics, lui, lesley, subcategories, arrigo,
# Nearest to question: grabbed, ejecting, salazar, pave, travers, pont, demian, megalopolis,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.5597 0.4267 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.4129 0.4329 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.3017 0.4420 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.1650 0.5014 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.0471 0.4536 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.9774 0.4198 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8656 0.4116 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7185 0.4079 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.6350 0.4169 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.4938 0.4282 sec/batch
# Nearest to called: nights, passageway, indiscernibles, hartsfield, turvy, flanking, zoramites, ureter,
# Nearest to so: murdered, intracranial, racquetball, clitoridectomy, amazona, eng, endocytosis, flatulence,
# Nearest to can: neg, o, canarias, thawing, brassy, dempster, abingdon, harp,
# Nearest to zero: example, shahade, endorsements, asdb, instinct, relentless, staircase, transmitting,
# Nearest to as: business, titanium, wakefulness, worsen, louisiane, bez, herzog, kingsley,
# Nearest to years: semigroup, housewife, hostname, disingenuous, somehow, dolchsto, memorize, incommunicado,
# Nearest to have: owyn, absolutes, awaiting, ministries, rivi, loco, glows, kaye,
# Nearest to new: risen, electroshock, sigur, inflation, stocking, bowls, burgh, ratzenberger,
# Nearest to issue: handwriting, mescaline, brad, johor, absurd, kober, walt, discusses,
# Nearest to assembly: pliocene, bias, inflation, ajmer, asymptotically, jh, thabit, congreve,
# Nearest to paris: serra, luxuries, helms, bhojpuri, arbuckle, shaken, mtv, solent,
# Nearest to recorded: merrill, pepe, founding, release, sumitomo, hplc, centred, taxation,
# Nearest to event: recap, enormously, analysis, tefan, omnibus, hydras, shoreditch, blackbody,
# Nearest to frac: woolworth, gie, jeux, classifies, monotonicity, potassium, savanna, graf,
# Nearest to primarily: mordor, yugoslavian, macroeconomics, lesley, subcategories, lui, supposing, herschel,
# Nearest to question: ejecting, grabbed, pave, salazar, megalopolis, demian, competitor, haemophilia,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4362 0.4306 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.3151 0.4275 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.3014 0.4250 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.1540 0.4219 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 15.0854 0.4251 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.9604 0.4348 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.7522 0.4505 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.6867 0.5266 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.6494 0.4403 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.5340 0.4310 sec/batch
# Nearest to called: nights, passageway, indiscernibles, flanking, hartsfield, zoramites, compression, turvy,
# Nearest to so: murdered, intracranial, endocytosis, amazona, clitoridectomy, racquetball, quintilian, eng,
# Nearest to can: neg, canarias, o, dempster, harp, abingdon, vengeance, amc,
# Nearest to zero: endorsements, example, shahade, bronze, confessed, transmitting, oscar, incubators,
# Nearest to as: business, titanium, wakefulness, interstate, bez, worsen, herzog, kingsley,
# Nearest to years: housewife, semigroup, hostname, dolchsto, disingenuous, somehow, memorize, incommunicado,
# Nearest to have: owyn, absolutes, rivi, awaiting, glows, ministries, loco, skier,
# Nearest to new: risen, electroshock, bowls, stocking, sigur, palacio, newell, burgh,
# Nearest to issue: handwriting, mescaline, kober, brad, absurd, discusses, walt, johor,
# Nearest to assembly: bias, pliocene, inflation, ajmer, asymptotically, backpack, varsity, jolla,
# Nearest to paris: serra, helms, luxuries, shaken, bhojpuri, outskirts, solent, arbuckle,
# Nearest to recorded: merrill, founding, pepe, release, centred, sumitomo, taxation, hplc,
# Nearest to event: recap, analysis, hydras, enormously, hath, omnibus, shoreditch, ische,
# Nearest to frac: woolworth, classifies, jeux, gie, monotonicity, potassium, graf, savanna,
# Nearest to primarily: macroeconomics, mordor, yugoslavian, lesley, subcategories, supposing, consulting, lui,
# Nearest to question: pave, ejecting, grabbed, megalopolis, optics, competitor, demian, haemophilia,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4459 0.4282 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.3697 0.4260 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.2453 0.4270 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1111 0.4246 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.1387 0.4200 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.9947 0.4219 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.8727 0.4214 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8166 0.4211 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.7262 0.4260 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.7182 0.4348 sec/batch
# Nearest to called: nights, hartsfield, compression, indiscernibles, passageway, zoramites, flanking, marl,
# Nearest to so: murdered, intracranial, racquetball, endocytosis, insulation, eng, amazona, quintilian,
# Nearest to can: neg, canarias, o, amc, dempster, superconductivity, vengeance, sauber,
# Nearest to zero: endorsements, confessed, shahade, example, bronze, marienburg, quilt, transmitting,
# Nearest to as: business, titanium, antagonized, interstate, wakefulness, herzog, worsen, baryons,
# Nearest to years: semigroup, hostname, housewife, dolchsto, somehow, disingenuous, memorize, economical,
# Nearest to have: owyn, absolutes, awaiting, ministries, rivi, eutyches, glows, allowance,
# Nearest to new: risen, electroshock, bowls, stocking, burgh, loneliness, palacio, habitus,
# Nearest to issue: handwriting, mescaline, absurd, kober, brad, johor, discusses, darling,
# Nearest to assembly: bias, pliocene, inflation, ajmer, asymptotically, backpack, varsity, jolla,
# Nearest to paris: luxuries, helms, bhojpuri, serra, solent, arbuckle, shaken, catesby,
# Nearest to recorded: merrill, release, founding, pepe, centred, sumitomo, taxation, fas,
# Nearest to event: recap, analysis, blackbody, hydras, hath, shoreditch, kryptonite, omnibus,
# Nearest to frac: woolworth, monotonicity, classifies, gie, potassium, jeux, savanna, graf,
# Nearest to primarily: macroeconomics, mordor, lesley, yugoslavian, subcategories, supposing, lui, arrigo,
# Nearest to question: pave, ejecting, grabbed, optics, demian, megalopolis, competitor, pont,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.6393 0.4845 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.4902 0.5417 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.3636 0.4232 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3320 0.4197 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.3011 0.4227 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.2011 0.4237 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.1151 0.3085 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9314 0.4276 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.9431 0.4255 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.7694 0.4226 sec/batch
# Nearest to called: nights, hartsfield, zoramites, indiscernibles, compression, przewodnicz, passageway, marl,
# Nearest to so: murdered, intracranial, eng, caves, endocytosis, insulation, vuk, quintilian,
# Nearest to can: neg, canarias, o, dempster, amc, mandated, forsyth, hyperfocal,
# Nearest to zero: of, the, four, to, one, two, endorsements, serpento,
# Nearest to as: business, titanium, antagonized, interstate, racquet, redbrick, zurich, francois,
# Nearest to years: hostname, housewife, somehow, semigroup, disingenuous, dolchsto, incommunicado, rider,
# Nearest to have: awaiting, owyn, eliminated, glows, absolutes, ministries, eutyches, washington,
# Nearest to new: risen, electroshock, dirac, palacio, loneliness, habitus, stocking, desegregate,
# Nearest to issue: handwriting, absurd, mescaline, brad, kober, discusses, johor, kpa,
# Nearest to assembly: bias, pliocene, inflation, ajmer, backpack, varsity, jolla, asymptotically,
# Nearest to paris: helms, bhojpuri, shaken, solent, serra, luxuries, arbuckle, mines,
# Nearest to recorded: merrill, release, founding, pepe, taxation, sumitomo, breeders, centred,
# Nearest to event: recap, hydras, kryptonite, blackbody, shoreditch, hath, enormously, analysis,
# Nearest to frac: woolworth, monotonicity, classifies, gie, graf, potassium, jeux, savanna,
# Nearest to primarily: macroeconomics, yugoslavian, mordor, lesley, subcategories, supposing, lui, breaching,
# Nearest to question: ejecting, megalopolis, pave, optics, grabbed, pont, spink, competitor,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.7046 0.4269 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.6145 0.4206 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.4606 0.4236 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.5393 0.4466 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3010 0.5166 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.3047 0.4987 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1391 0.4247 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0755 0.4112 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0396 0.4132 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0095 0.4145 sec/batch
# Nearest to called: nights, zoramites, glas, he, hartsfield, compression, indiscernibles, marl,
# Nearest to so: murdered, endocytosis, insulation, intracranial, gyms, flatulence, clitoridectomy, eng,
# Nearest to can: o, neg, maximus, canarias, mandated, sippar, halberd, ambitious,
# Nearest to zero: one, two, the, of, in, and, for, four,
# Nearest to as: the, of, in, and, to, a, zero, for,
# Nearest to years: hostname, housewife, somehow, rider, disingenuous, mannlicher, incommunicado, semigroup,
# Nearest to have: the, of, to, in, and, eliminated, for, awaiting,
# Nearest to new: on, the, burgh, palacio, risen, electroshock, while, and,
# Nearest to issue: handwriting, mescaline, brad, absurd, discusses, kober, johor, work,
# Nearest to assembly: bias, pliocene, inflation, ajmer, asymptotically, shareholders, slick, varsity,
# Nearest to paris: serra, mobiles, shaken, helms, bhojpuri, mines, solent, europeans,
# Nearest to recorded: founding, merrill, release, taxation, unification, pepe, centred, sextus,
# Nearest to event: hydras, recap, hath, kryptonite, blackbody, tallahassee, sandwich, apostates,
# Nearest to frac: woolworth, monotonicity, classifies, graf, savanna, gie, potassium, liberated,
# Nearest to primarily: macroeconomics, mordor, yugoslavian, subcategories, lesley, azathoth, arrigo, supposing,
# Nearest to question: ejecting, pave, competitor, optics, megalopolis, grabbed, jahwist, salazar,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 12.0342 0.4197 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8232 0.4158 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.7855 0.4207 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.7139 0.4203 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.7532 0.4198 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.6170 0.4221 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.3915 0.4292 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.4073 0.4352 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3724 0.4882 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.2997 0.4834 sec/batch
# Nearest to called: he, for, first, over, by, that, s, zoramites,
# Nearest to so: as, that, in, by, with, is, are, the,
# Nearest to can: by, the, it, is, of, and, a, some,
# Nearest to zero: two, three, one, four, of, five, in, the,
# Nearest to as: that, the, and, of, a, to, by, is,
# Nearest to years: in, two, zero, with, three, five, their, by,
# Nearest to have: to, of, by, is, the, a, that, are,
# Nearest to new: of, the, as, a, to, for, one, on,
# Nearest to issue: mescaline, brad, absurd, handwriting, discusses, darling, work, rabi,
# Nearest to assembly: bias, pliocene, inflation, ajmer, asymptotically, corporal, jh, shareholders,
# Nearest to paris: mobiles, helms, arbuckle, europeans, cabot, explaining, serra, bhojpuri,
# Nearest to recorded: founding, release, merrill, humbucker, sextus, taxation, prolog, unification,
# Nearest to event: recap, hath, tallahassee, hydras, mitosis, pilots, kryptonite, blackbody,
# Nearest to frac: woolworth, monotonicity, classifies, savanna, potassium, graf, gie, superiors,
# Nearest to primarily: mordor, yugoslavian, macroeconomics, lesley, azathoth, subcategories, breaching, upsilon,
# Nearest to question: competitor, ejecting, megalopolis, optics, jahwist, pave, flopped, tambourine,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3511 0.4239 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.1482 0.4234 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9479 0.4180 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.0305 0.4097 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 11.0098 0.4096 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.8359 0.4104 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.8508 0.4104 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8601 0.4129 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6596 0.4152 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.6101 0.4119 sec/batch
# Nearest to called: as, for, is, in, a, it, the, that,
# Nearest to so: it, for, as, that, be, are, there, is,
# Nearest to can: not, is, be, or, for, to, other, in,
# Nearest to zero: two, four, five, eight, six, one, three, nine,
# Nearest to as: the, a, in, that, or, for, of, it,
# Nearest to years: five, of, in, zero, three, two, one, the,
# Nearest to have: a, the, in, for, of, be, as, to,
# Nearest to new: one, was, of, to, the, first, with, that,
# Nearest to issue: absurd, mescaline, drew, work, brad, discusses, handwriting, darling,
# Nearest to assembly: bias, pliocene, inflation, ajmer, asymptotically, corporal, jh, slick,
# Nearest to paris: explaining, helms, organizing, bhojpuri, spiderweb, mobiles, arbuckle, cabot,
# Nearest to recorded: founding, release, merrill, humbucker, prolog, unification, sextus, pepe,
# Nearest to event: recap, tallahassee, sorted, hath, hydras, sandwich, blackbody, mitosis,
# Nearest to frac: woolworth, monotonicity, classifies, savanna, graf, gie, massoud, potassium,
# Nearest to primarily: mordor, yugoslavian, could, lesley, on, only, azathoth, zero,
# Nearest to question: competitor, ejecting, optics, megalopolis, pave, effective, tambourine, flopped,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.5100 0.4229 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.6338 0.4408 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.4936 0.5038 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.4614 0.4586 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.4700 0.4188 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.2072 0.4191 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.3430 0.4206 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2557 0.4205 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.0695 0.4225 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.0788 0.4231 sec/batch
# Nearest to called: that, it, with, to, be, of, a, from,
# Nearest to so: for, of, to, not, be, only, that, and,
# Nearest to can: be, for, use, not, this, other, that, have,
# Nearest to zero: two, five, four, six, three, one, eight, nine,
# Nearest to as: and, a, the, of, be, to, with, by,
# Nearest to years: zero, five, by, three, in, four, two, of,
# Nearest to have: be, to, as, a, are, and, on, has,
# Nearest to new: was, the, a, and, by, to, that, in,
# Nearest to issue: through, drew, on, of, also, the, in, wilbury,
# Nearest to assembly: inflation, bias, corporal, pliocene, slick, ajmer, shareholders, asymptotically,
# Nearest to paris: helms, mobiles, organizing, arbuckle, bhojpuri, cabot, spiderweb, coronets,
# Nearest to recorded: founding, merrill, unification, release, prolog, sextus, humbucker, principle,
# Nearest to event: recap, sandwich, tallahassee, butler, televizija, sorted, even, actor,
# Nearest to frac: woolworth, monotonicity, classifies, savanna, massoud, gie, potassium, joyful,
# Nearest to primarily: mordor, could, only, the, under, yugoslavian, for, there,
# Nearest to question: competitor, ejecting, optics, faced, pave, savate, megalopolis, australian,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.0701 0.4246 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0732 0.4198 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.9742 0.1866 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.8719 0.4214 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.7993 0.4284 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.7424 0.4455 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.6229 0.5379 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.6935 0.4236 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.5522 0.4218 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4609 0.4302 sec/batch
# Nearest to called: this, as, the, is, more, are, such, in,
# Nearest to so: be, that, or, to, from, with, most, can,
# Nearest to can: be, are, more, that, a, if, used, or,
# Nearest to zero: two, four, five, three, one, six, seven, nine,
# Nearest to as: be, to, of, the, is, been, was, it,
# Nearest to years: zero, five, two, one, four, three, the, of,
# Nearest to have: of, the, to, has, is, with, a, there,
# Nearest to new: the, was, of, in, as, to, had, and,
# Nearest to issue: six, drew, is, through, work, however, out, number,
# Nearest to assembly: bias, slick, inflation, pliocene, corporal, ajmer, scriptures, pxe,
# Nearest to paris: war, age, cabot, easily, large, reported, helms, catesby,
# Nearest to recorded: founding, release, unification, sextus, prolog, merrill, principle, bluerhinos,
# Nearest to event: sorted, recap, though, hath, tallahassee, butler, sandwich, pilots,
# Nearest to frac: woolworth, monotonicity, classifies, savanna, gie, error, massoud, potassium,
# Nearest to primarily: are, even, s, that, only, less, found, had,
# Nearest to question: competitor, ejecting, might, faced, optics, rouse, savate, australian,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.5116 0.4411 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.4828 0.4345 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.2971 0.4286 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1130 0.4167 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.1676 0.4173 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.2083 0.4211 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.3055 0.4205 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.1735 0.4245 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 8.9951 0.4295 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0346 0.4388 sec/batch
# Nearest to called: is, which, that, and, are, there, a, in,
# Nearest to so: be, that, to, other, is, they, or, in,
# Nearest to can: is, are, which, be, or, if, that, use,
# Nearest to zero: two, five, one, three, six, four, eight, nine,
# Nearest to as: the, of, and, in, is, that, to, which,
# Nearest to years: five, zero, two, eight, one, three, six, four,
# Nearest to have: there, are, the, be, that, of, as, is,
# Nearest to new: was, of, s, in, zero, the, and, one,
# Nearest to issue: those, does, members, but, system, first, non, has,
# Nearest to assembly: bias, slick, pliocene, varsity, inflation, scriptures, ajmer, setting,
# Nearest to paris: age, war, governmental, leader, population, cabot, kinds, great,
# Nearest to recorded: release, founding, prolog, unification, sextus, bluerhinos, principle, up,
# Nearest to event: though, however, back, than, their, when, or, s,
# Nearest to frac: woolworth, monotonicity, classifies, savanna, liberated, massoud, error, potassium,
# Nearest to primarily: than, of, its, between, even, per, under, time,
# Nearest to question: competitor, ejecting, these, rouse, savate, might, itself, optics,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.0898 0.5043 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0771 0.4285 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.6712 0.4284 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.8381 0.4246 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.7860 0.4208 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.7480 0.4214 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7349 0.4244 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.7719 0.4224 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.4532 0.4260 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.6608 0.4225 sec/batch
# Nearest to called: the, to, that, be, a, of, it, some,
# Nearest to so: is, that, this, will, be, a, and, it,
# Nearest to can: be, example, is, are, if, because, that, then,
# Nearest to zero: two, five, four, three, one, six, eight, seven,
# Nearest to as: and, the, by, a, or, in, that, some,
# Nearest to years: zero, over, five, of, two, four, three, under,
# Nearest to have: to, that, some, the, is, by, of, which,
# Nearest to new: in, was, of, to, first, the, and, for,
# Nearest to issue: for, to, and, they, a, members, but, from,
# Nearest to assembly: attempt, one, three, seven, year, general, slick, last,
# Nearest to paris: age, years, independent, great, governmental, began, war, member,
# Nearest to recorded: human, own, had, release, small, founding, unification, prolog,
# Nearest to event: more, have, has, result, there, but, because, much,
# Nearest to frac: woolworth, monotonicity, liberated, classifies, error, savanna, massoud, potassium,
# Nearest to primarily: power, as, many, s, much, and, history, those,
# Nearest to question: possible, given, cannot, make, might, different, either, itself,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6503 0.4242 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.4084 0.4254 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4465 0.4327 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.4800 0.4582 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.3811 0.5168 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.2771 0.4184 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2394 0.4215 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.3915 0.4248 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.2802 0.4245 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2491 0.4204 sec/batch
# Nearest to called: are, that, not, the, is, they, of, to,
# Nearest to so: this, is, are, will, the, a, to, and,
# Nearest to can: is, example, are, not, it, be, or, have,
# Nearest to zero: two, three, four, one, five, six, nine, eight,
# Nearest to as: the, of, a, to, that, and, for, is,
# Nearest to years: the, of, was, in, and, period, year, on,
# Nearest to have: that, the, is, of, a, to, or, as,
# Nearest to new: of, and, on, was, the, first, had, united,
# Nearest to issue: to, in, their, the, place, but, a, of,
# Nearest to assembly: position, year, state, gained, issue, time, strong, power,
# Nearest to paris: began, age, states, years, was, great, during, until,
# Nearest to recorded: th, was, popular, success, early, first, where, soon,
# Nearest to event: than, many, large, have, did, without, this, because,
# Nearest to frac: woolworth, liberated, monotonicity, error, classifies, establishments, massoud, savanna,
# Nearest to primarily: over, long, these, more, to, its, well, only,
# Nearest to question: possible, if, will, therefore, be, than, make, have,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.4500 0.4225 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 7.9713 0.4208 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.2752 0.4188 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1043 0.4186 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 7.9340 0.4198 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.0266 0.4212 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.0231 0.4307 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0183 0.4548 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 7.9662 0.0768 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.7690 0.4272 sec/batch
# Nearest to called: and, the, a, that, be, has, it, of,
# Nearest to so: a, that, to, or, be, example, this, but,
# Nearest to can: be, are, is, if, or, that, example, not,
# Nearest to zero: two, five, four, three, nine, six, one, seven,
# Nearest to as: by, and, of, for, the, a, to, that,
# Nearest to years: zero, population, five, over, two, under, age, th,
# Nearest to have: to, that, this, for, or, and, other, is,
# Nearest to new: of, the, in, on, and, by, a, was,
# Nearest to issue: the, to, since, on, of, public, have, place,
# Nearest to assembly: held, prime, national, president, members, at, party, september,
# Nearest to paris: continued, april, war, years, th, began, named, becoming,
# Nearest to recorded: early, first, in, but, the, over, produced, was,
# Nearest to event: but, a, would, for, less, this, so, there,
# Nearest to frac: woolworth, liberated, monotonicity, gives, massoud, plays, values, establishments,
# Nearest to primarily: as, is, however, most, of, those, or, only,
# Nearest to question: therefore, own, with, if, that, which, not, work,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.8260 0.4246 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.8946 0.4205 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.6828 0.4227 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.9090 0.4186 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.6628 0.4124 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.5527 0.4180 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.6226 0.4271 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6152 0.4207 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.5640 0.4230 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.2922 0.4218 sec/batch
# Nearest to called: is, a, be, for, used, also, other, example,
# Nearest to so: be, it, a, that, example, they, or, which,
# Nearest to can: be, or, example, is, using, that, it, all,
# Nearest to zero: two, five, four, six, three, one, nine, seven,
# Nearest to as: the, of, but, a, been, on, that, and,
# Nearest to years: zero, five, two, four, population, over, in, three,
# Nearest to have: that, in, has, the, and, other, to, or,
# Nearest to new: of, and, the, at, to, by, had, in,
# Nearest to issue: to, and, at, itself, among, of, who, were,
# Nearest to assembly: prime, held, state, elected, terms, executive, political, nine,
# Nearest to paris: during, one, four, war, ii, continued, met, three,
# Nearest to recorded: on, the, was, time, as, of, in, one,
# Nearest to event: the, but, at, to, though, as, were, of,
# Nearest to frac: woolworth, liberated, gives, surrounding, establishments, massoud, size, regularly,
# Nearest to primarily: it, some, these, is, this, which, the, to,
# Nearest to question: be, which, that, this, should, fact, therefore, could,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.4110 0.4355 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.3729 0.4626 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.5566 0.5316 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.4798 0.4518 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.2903 0.4253 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.3126 0.4242 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.4713 0.4222 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.4343 0.4295 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.0997 0.4214 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.1406 0.4177 sec/batch
# Nearest to called: a, is, which, and, or, to, for, also,
# Nearest to so: and, be, they, not, to, other, which, a,
# Nearest to can: is, be, or, are, will, form, a, to,
# Nearest to zero: two, three, five, six, four, one, nine, seven,
# Nearest to as: of, and, a, the, in, but, by, to,
# Nearest to years: population, zero, over, age, five, people, in, year,
# Nearest to have: but, are, and, that, as, a, some, to,
# Nearest to new: in, s, was, of, the, states, united, by,
# Nearest to issue: not, this, to, their, the, they, other, however,
# Nearest to assembly: elected, president, prime, political, executive, held, chief, national,
# Nearest to paris: war, he, until, ii, seven, united, nine, three,
# Nearest to recorded: s, several, at, the, of, on, early, as,
# Nearest to event: their, to, the, a, many, in, for, either,
# Nearest to frac: woolworth, include, values, liberated, then, establishments, usually, implies,
# Nearest to primarily: and, to, in, are, or, no, the, as,
# Nearest to question: should, that, may, be, not, some, they, would,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.1807 0.4255 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.1376 0.4241 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.1918 0.4294 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.2733 0.4274 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.0095 0.4270 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 6.9538 0.4288 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.1690 0.4943 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.0185 0.4759 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0112 0.4300 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0060 0.4197 sec/batch
# Nearest to called: a, is, which, for, or, have, these, because,
# Nearest to so: which, that, be, not, this, they, is, all,
# Nearest to can: is, if, be, using, possible, not, or, so,
# Nearest to zero: two, six, five, one, four, three, nine, eight,
# Nearest to as: the, and, a, that, in, of, by, to,
# Nearest to years: five, year, in, one, four, six, age, two,
# Nearest to have: that, a, most, or, the, are, it, be,
# Nearest to new: in, was, on, the, by, and, of, s,
# Nearest to issue: to, by, the, but, a, many, this, that,
# Nearest to assembly: elected, president, prime, executive, minister, elections, held, vote,
# Nearest to paris: nine, new, seven, one, was, eight, three, until,
# Nearest to recorded: on, at, off, with, and, s, in, was,
# Nearest to event: a, to, as, have, that, on, and, in,
# Nearest to frac: woolworth, implies, values, nevertheless, route, expression, gives, technique,
# Nearest to primarily: a, are, as, of, other, its, that, only,
# Nearest to question: so, how, that, other, believe, not, they, may,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.1175 0.4235 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.7695 0.4194 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.7848 0.4010 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 6.9541 0.4059 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9222 0.4133 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.8561 0.4144 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.0871 0.4170 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.6963 0.4253 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 6.8761 0.4433 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9774 0.5295 sec/batch
# Nearest to called: and, is, this, be, which, or, it, not,
# Nearest to so: not, a, and, have, is, which, be, other,
# Nearest to can: is, be, typically, using, cannot, or, used, specific,
# Nearest to zero: two, five, four, three, one, six, nine, eight,
# Nearest to as: and, the, it, of, some, in, a, that,
# Nearest to years: year, zero, was, age, new, until, under, in,
# Nearest to have: not, and, be, a, some, is, as, those,
# Nearest to new: was, had, in, after, three, states, first, four,
# Nearest to issue: to, the, their, agreed, for, but, not, public,
# Nearest to assembly: elected, vote, appointed, elections, executive, members, government, council,
# Nearest to paris: france, three, was, new, nine, last, seven, after,
# Nearest to recorded: was, first, early, s, made, song, at, records,
# Nearest to event: the, most, had, but, in, their, on, to,
# Nearest to frac: f, woolworth, define, right, n, plane, values, functions,
# Nearest to primarily: the, most, of, and, their, but, only, have,
# Nearest to question: own, have, but, not, all, be, how, subject,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.6399 0.4473 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7005 0.4271 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.6922 0.4275 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.7904 0.4209 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.8563 0.4179 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6001 0.3710 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.6846 0.4242 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.7341 0.4247 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.5572 0.4268 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.6575 0.4275 sec/batch
# Nearest to called: so, this, that, as, be, it, a, have,
# Nearest to so: that, it, be, different, not, this, called, as,
# Nearest to can: different, such, be, used, if, are, use, or,
# Nearest to zero: two, six, three, five, four, one, seven, nine,
# Nearest to as: it, have, for, which, this, in, the, a,
# Nearest to years: age, year, after, of, the, live, in, birth,
# Nearest to have: it, as, is, that, a, the, to, some,
# Nearest to new: first, on, s, in, at, and, of, the,
# Nearest to issue: in, the, by, on, public, did, after, to,
# Nearest to assembly: vote, members, elected, elections, council, executive, government, held,
# Nearest to paris: moved, george, until, france, british, he, york, his,
# Nearest to recorded: first, song, early, s, was, after, ever, year,
# Nearest to event: on, and, it, previous, of, to, most, in,
# Nearest to frac: define, f, constant, x, find, value, values, z,
# Nearest to primarily: some, many, within, is, between, as, most, which,
# Nearest to question: that, claim, which, not, by, all, some, how,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.5763 0.4268 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.4424 0.4280 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.5662 0.4425 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.4847 0.4967 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5217 0.4309 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.2858 0.4236 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.2542 0.4269 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.3182 0.4340 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4458 0.4265 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.4837 0.4233 sec/batch
# Nearest to called: is, this, or, which, to, a, there, that,
# Nearest to so: this, to, that, not, is, but, it, some,
# Nearest to can: is, cannot, possible, be, allows, are, useful, using,
# Nearest to zero: two, four, five, three, six, one, seven, eight,
# Nearest to as: to, and, other, the, a, for, of, in,
# Nearest to years: population, age, birth, live, four, five, over, two,
# Nearest to have: as, to, but, or, some, a, with, most,
# Nearest to new: was, one, world, of, became, by, s, the,
# Nearest to issue: to, among, the, but, would, not, them, some,
# Nearest to assembly: elected, elections, vote, council, branch, executive, appointed, government,
# Nearest to paris: until, met, king, france, took, one, george, died,
# Nearest to recorded: on, band, during, song, records, up, rock, songs,
# Nearest to event: but, in, on, at, which, a, about, to,
# Nearest to frac: x, f, quantity, n, constant, function, p, z,
# Nearest to primarily: as, and, some, into, non, to, the, most,
# Nearest to question: whether, given, claim, that, existence, say, merely, knowledge,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.2853 0.4207 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3635 0.4163 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.3114 0.4194 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4429 0.4378 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.3376 0.5123 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.0937 0.4912 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.2631 0.4684 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.3002 0.4935 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.1321 0.5479 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3332 0.5582 sec/batch
# Nearest to called: is, which, it, a, used, an, or, all,
# Nearest to so: this, not, be, any, it, that, is, if,
# Nearest to can: be, are, is, each, example, cannot, if, different,
# Nearest to zero: two, three, five, six, four, seven, nine, eight,
# Nearest to as: to, the, for, of, by, have, in, an,
# Nearest to years: year, age, population, brought, over, part, newly, kingdom,
# Nearest to have: other, as, to, this, which, a, or, most,
# Nearest to new: the, of, in, was, s, were, and, world,
# Nearest to issue: their, of, the, in, being, has, to, as,
# Nearest to assembly: vote, elected, elections, branch, legislative, government, executive, election,
# Nearest to paris: france, king, met, london, july, soon, john, after,
# Nearest to recorded: recording, the, made, records, featured, on, s, rock,
# Nearest to event: a, to, which, on, is, have, the, in,
# Nearest to frac: k, constant, x, f, z, v, limit, y,
# Nearest to primarily: through, as, some, many, is, has, are, the,
# Nearest to question: merely, not, claim, this, whether, that, our, say,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1614 0.4567 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0528 0.4334 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2540 0.4697 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.1507 0.4803 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1099 0.4482 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.1531 0.4980 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2261 0.4900 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.9150 0.4889 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0083 0.5017 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 5.9871 0.5672 sec/batch
# Nearest to called: is, which, a, it, as, or, similar, there,
# Nearest to so: not, be, is, any, as, it, or, even,
# Nearest to can: is, useful, be, possible, typically, or, always, each,
# Nearest to zero: four, five, two, three, eight, one, six, nine,
# Nearest to as: a, the, of, to, it, which, or, for,
# Nearest to years: age, population, the, from, people, year, in, until,
# Nearest to have: of, it, that, as, a, they, has, be,
# Nearest to new: was, s, first, at, on, began, in, before,
# Nearest to issue: that, stated, to, their, have, being, the, as,
# Nearest to assembly: vote, legislative, elected, branch, executive, elections, cabinet, seats,
# Nearest to paris: france, king, london, he, new, named, his, was,
# Nearest to recorded: records, s, early, going, in, musical, style, on,
# Nearest to event: to, has, in, have, these, more, although, as,
# Nearest to frac: constant, z, x, y, function, defined, f, k,
# Nearest to primarily: and, more, as, which, has, are, of, have,
# Nearest to question: not, our, how, merely, that, even, of, view,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.1244 0.6129 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.0743 0.5035 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.2318 0.4815 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.1484 0.4842 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9488 0.4864 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.1352 0.4858 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 5.9766 0.4817 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.8826 0.4848 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9397 0.4832 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.0425 0.4933 sec/batch
# Nearest to called: is, be, are, which, this, a, more, so,
# Nearest to so: is, that, have, to, be, it, not, this,
# Nearest to can: be, are, typically, used, specific, such, or, example,
# Nearest to zero: five, two, three, six, four, one, nine, seven,
# Nearest to as: the, to, of, with, and, a, this, their,
# Nearest to years: over, under, age, people, birth, in, year, population,
# Nearest to have: that, some, it, this, many, to, more, has,
# Nearest to new: was, in, s, during, first, after, states, became,
# Nearest to issue: did, in, people, political, failed, to, the, and,
# Nearest to assembly: vote, legislative, elected, elections, council, members, executive, constitution,
# Nearest to paris: france, york, one, british, st, george, seven, september,
# Nearest to recorded: recording, songs, band, records, ever, rock, song, music,
# Nearest to event: to, up, an, being, in, with, place, the,
# Nearest to frac: z, constant, f, x, function, q, y, n,
# Nearest to primarily: its, most, the, of, but, has, is, more,
# Nearest to question: questions, our, how, that, what, thus, answer, person,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0401 0.5254 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9498 0.3556 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9249 0.5326 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 5.9541 0.4813 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.8719 0.4805 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.8804 0.4823 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9600 0.4862 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.8048 0.4820 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.7610 0.4856 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8308 0.4789 sec/batch
# Nearest to called: is, be, this, more, it, with, are, that,
# Nearest to so: for, be, this, more, not, that, if, it,
# Nearest to can: are, problem, or, example, possible, be, different, is,
# Nearest to zero: two, five, four, three, six, seven, one, nine,
# Nearest to as: of, the, to, in, there, from, most, by,
# Nearest to years: birth, age, live, female, deaths, and, under, year,
# Nearest to have: to, but, as, some, has, of, other, that,
# Nearest to new: the, s, in, and, was, at, first, by,
# Nearest to issue: upon, after, claimed, seek, political, response, in, opposed,
# Nearest to assembly: legislative, elected, vote, elections, council, parliament, members, branch,
# Nearest to paris: one, was, nine, three, six, edward, august, moved,
# Nearest to recorded: recording, band, record, songs, career, music, played, song,
# Nearest to event: at, the, of, still, in, about, also, a,
# Nearest to frac: function, x, n, constant, sum, z, y, f,
# Nearest to primarily: due, has, within, is, its, much, to, of,
# Nearest to question: questions, that, our, person, merely, not, principles, what,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.8753 0.4829 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6813 0.5009 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.5797 0.5012 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.6771 0.5091 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7151 0.4747 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8542 0.4238 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.7115 0.4267 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.6664 0.4158 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.7070 0.4132 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.7751 0.4134 sec/batch
# Nearest to called: is, this, are, so, it, with, usually, a,
# Nearest to so: is, be, this, are, it, or, that, not,
# Nearest to can: be, or, are, possible, is, using, useful, different,
# Nearest to zero: two, five, three, four, six, seven, one, eight,
# Nearest to as: to, in, the, and, of, most, it, by,
# Nearest to years: age, population, birth, female, male, migration, deaths, live,
# Nearest to have: more, and, they, to, as, the, in, may,
# Nearest to new: s, by, of, had, the, including, during, was,
# Nearest to issue: public, interests, freedom, were, did, not, upon, no,
# Nearest to assembly: elected, council, legislative, vote, branch, elections, parliament, judicial,
# Nearest to paris: ii, french, france, edward, british, charles, king, war,
# Nearest to recorded: recording, band, songs, recordings, titled, music, album, song,
# Nearest to event: on, the, at, most, by, of, as, only,
# Nearest to frac: x, n, sum, y, z, constant, equation, p,
# Nearest to primarily: due, particularly, most, lack, as, with, in, its,
# Nearest to question: questions, our, that, not, whether, existence, does, but,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 5.7871 0.4194 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 5.4999 0.4189 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 5.6029 0.4185 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 5.7275 0.4186 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 5.5863 0.4225 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 5.6760 0.4349 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 5.6449 0.4563 sec/batch
# ...
# Nearest to issue: matters, involvement, democracy, decision, freedom, did, actions, accept,
# Nearest to assembly: legislative, elections, elected, parliament, legislature, constitution, parliamentary, unicameral,
# Nearest to paris: france, french, philippe, de, charles, birthplace, frederick, louis,
# Nearest to recorded: recording, album, songs, band, song, recordings, albums, rock,
# Nearest to event: the, would, a, another, time, at, but, on,
# Nearest to frac: sum, equation, x, n, constant, f, cdot, p,
# Nearest to primarily: most, other, has, relatively, areas, especially, largely, its,
# Nearest to question: questions, statements, moral, whether, knowledge, arguments, not, statement,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.6712 0.4184 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6009 0.4192 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6881 0.4286 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.7270 0.4586 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7742 0.5094 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.7250 0.4257 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.7327 0.4183 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6628 0.4187 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.7763 0.4135 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7685 0.4010 sec/batch
# Nearest to called: is, are, different, a, this, an, unique, which,
# Nearest to so: this, be, it, that, is, not, because, make,
# Nearest to can: be, or, allows, using, because, useful, is, necessary,
# Nearest to zero: two, three, five, four, six, one, seven, nine,
# Nearest to as: in, and, other, some, this, the, to, which,
# Nearest to years: age, birth, male, population, female, total, rate, deaths,
# Nearest to have: they, there, some, that, as, or, no, not,
# Nearest to new: states, united, including, s, in, home, major, the,
# Nearest to issue: public, continue, did, subsequent, attempt, post, however, debate,
# Nearest to assembly: legislative, elected, ministers, elections, parliament, branch, judiciary, cabinet,
# Nearest to paris: france, french, louis, ii, italian, de, philippe, commissioned,
# Nearest to recorded: recording, band, recordings, songs, records, album, pop, albums,
# Nearest to event: on, through, at, to, will, about, than, the,
# Nearest to frac: sum, equation, x, y, n, pi, cos, vector,
# Nearest to primarily: based, some, specific, most, as, although, to, however,
# Nearest to question: questions, knowledge, that, statements, existence, whether, notion, answer,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5977 0.4086 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.7103 0.4050 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7369 0.4069 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6645 0.4104 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7424 0.4092 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6873 0.4172 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.6210 0.4309 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.6848 0.4326 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.7194 0.5205 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6431 0.4461 sec/batch
# Nearest to called: is, it, this, examples, also, are, there, unique,
# Nearest to so: that, will, can, it, because, not, always, do,
# Nearest to can: is, be, if, possible, depending, simple, useful, will,
# Nearest to zero: four, five, two, three, six, seven, one, nine,
# Nearest to as: in, and, which, of, to, by, the, a,
# Nearest to years: age, population, birth, five, zero, year, male, female,
# Nearest to have: to, they, that, it, there, a, this, may,
# Nearest to new: was, s, york, at, founded, in, on, first,
# Nearest to issue: by, continue, terms, attempts, further, certain, debate, for,
# Nearest to assembly: legislative, elections, constitution, elected, ministers, branch, unicameral, legislature,
# Nearest to paris: louis, france, de, french, iii, named, le, commissioned,
# Nearest to recorded: recording, records, band, record, charts, rock, chart, pop,
# Nearest to event: time, events, that, way, about, it, actually, this,
# Nearest to frac: sum, equation, constant, x, n, cos, pi, z,
# Nearest to primarily: has, other, although, and, mainly, largely, parts, countries,
# Nearest to question: whether, statements, questions, fact, statement, truth, assert, any,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6756 0.4237 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.7150 0.4212 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5821 0.4133 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.6207 0.4111 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6315 0.4120 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6126 0.4114 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.6917 0.4114 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7799 0.4134 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.7934 0.4095 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5814 0.4137 sec/batch
# Nearest to called: is, a, which, some, examples, with, example, means,
# Nearest to so: not, always, will, same, this, if, another, way,
# Nearest to can: be, is, if, certain, simple, depending, must, instance,
# Nearest to zero: two, five, four, three, six, one, nine, seven,
# Nearest to as: the, a, of, to, and, with, some, it,
# Nearest to years: age, five, male, population, birth, zero, female, year,
# Nearest to have: some, the, that, to, as, and, there, most,
# Nearest to new: was, first, founded, s, states, united, in, york,
# Nearest to issue: government, continue, legal, political, policy, members, policies, agreed,
# Nearest to assembly: legislative, ministers, unicameral, elected, constitution, cabinet, members, parliament,
# Nearest to paris: france, french, de, la, philippe, henri, seven, ii,
# Nearest to recorded: songs, rock, band, album, recording, singing, pop, recordings,
# Nearest to event: time, to, out, go, events, actually, they, a,
# Nearest to frac: sum, x, equation, pi, n, y, constant, cdot,
# Nearest to primarily: most, mainly, and, been, of, since, growing, in,
# Nearest to question: questions, answer, statements, whether, not, necessarily, statement, truth,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.6773 0.4221 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6536 0.4374 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5150 0.5013 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5874 0.4372 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6439 0.4144 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.6605 0.4089 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6964 0.2009 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5602 0.4183 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6165 0.4163 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.6286 0.4155 sec/batch
# Nearest to called: this, which, example, a, all, is, an, the,
# Nearest to so: do, it, be, make, not, means, they, this,
# Nearest to can: are, usually, such, depending, used, be, types, specific,
# Nearest to zero: two, five, three, four, six, nine, seven, one,
# Nearest to as: which, to, their, other, been, the, and, in,
# Nearest to years: age, male, birth, female, over, population, rate, migration,
# Nearest to have: those, they, very, it, other, as, some, been,
# Nearest to new: first, york, s, founded, on, states, jersey, national,
# Nearest to issue: failed, for, continue, matters, membership, legal, citizens, initiative,
# Nearest to assembly: legislative, unicameral, members, cabinet, elections, serve, elected, branch,
# Nearest to paris: france, de, ii, louis, king, one, anne, charles,
# Nearest to recorded: band, rock, records, album, singing, ever, performances, concerts,
# Nearest to event: out, time, seeing, ever, end, up, missed, own,
# Nearest to frac: sum, equation, pi, cdot, constant, cos, x, int,
# Nearest to primarily: relatively, most, its, mostly, more, much, largely, country,
# Nearest to question: questions, whether, assert, answer, knowledge, not, arguments, merely,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5613 0.4176 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6503 0.4163 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5726 0.4159 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.4809 0.4155 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5928 0.4230 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.6037 0.4300 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5596 0.4802 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4154 0.4716 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.5208 0.4173 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5218 0.4054 sec/batch
# Nearest to called: is, form, which, a, example, are, there, hence,
# Nearest to so: be, this, that, simply, if, example, can, not,
# Nearest to can: be, possible, or, example, if, cannot, simple, are,
# Nearest to zero: five, four, two, three, one, six, seven, nine,
# Nearest to as: other, some, these, of, and, most, to, it,
# Nearest to years: male, age, rate, live, female, deaths, mortality, birth,
# Nearest to have: but, to, as, they, been, much, which, other,
# Nearest to new: of, and, began, on, s, became, york, was,
# Nearest to issue: opinion, matters, debate, members, stated, regarding, criticism, actions,
# Nearest to assembly: legislative, elected, parliamentary, parliament, branch, unicameral, ministers, elections,
# Nearest to paris: maurice, france, sur, le, charles, poet, painter, jean,
# Nearest to recorded: band, album, songs, rock, albums, song, records, concert,
# Nearest to event: long, at, down, place, ever, time, it, about,
# Nearest to frac: equation, sum, x, cdot, constant, n, cos, y,
# Nearest to primarily: and, its, has, largely, especially, the, with, much,
# Nearest to question: questions, that, whether, knowledge, existence, argument, how, what,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5925 0.4090 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5476 0.4119 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5381 0.4117 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5188 0.4106 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5991 0.4109 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6348 0.4136 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4499 0.4120 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4724 0.4162 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5855 0.4197 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.5215 0.4328 sec/batch
# Nearest to called: a, an, is, different, form, example, which, number,
# Nearest to so: this, it, be, that, only, is, if, can,
# Nearest to can: be, or, cannot, if, any, makes, useful, it,
# Nearest to zero: two, three, five, four, six, eight, one, nine,
# Nearest to as: of, the, other, but, in, that, this, is,
# Nearest to years: age, population, female, male, five, million, birth, growth,
# Nearest to have: some, but, are, which, more, only, that, by,
# Nearest to new: york, and, s, the, began, now, on, nine,
# Nearest to issue: efforts, government, opinion, however, policies, for, policy, freedom,
# Nearest to assembly: legislative, unicameral, elections, elected, branch, cabinet, seats, parliamentary,
# Nearest to paris: de, le, france, sur, ii, charles, louis, iii,
# Nearest to recorded: band, recording, album, albums, rock, records, songs, song,
# Nearest to event: actually, a, the, events, time, is, rest, at,
# Nearest to frac: sum, equation, x, cos, cdot, pi, z, n,
# Nearest to primarily: has, many, more, much, most, very, largely, especially,
# Nearest to question: whether, argument, that, questions, knowledge, reason, how, things,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5357 0.4919 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5265 0.4360 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4162 0.4188 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5336 0.4225 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5654 0.4182 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.4549 0.4176 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.4906 0.4167 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5546 0.4151 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4508 0.4156 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.4109 0.4165 sec/batch
# Nearest to called: this, is, where, a, are, an, different, it,
# Nearest to so: be, not, that, always, it, there, thus, any,
# Nearest to can: be, or, simple, cannot, using, if, used, because,
# Nearest to zero: two, four, five, one, six, three, eight, seven,
# Nearest to as: of, and, to, by, a, the, other, this,
# Nearest to years: population, age, rate, birth, five, growth, live, million,
# Nearest to have: there, are, as, it, or, other, more, this,
# Nearest to new: york, on, s, began, world, named, national, was,
# Nearest to issue: efforts, affairs, continue, government, policy, stated, regarding, political,
# Nearest to assembly: legislative, unicameral, elected, parliamentary, parliament, president, constitution, ministers,
# Nearest to paris: france, charles, iii, louis, le, de, ii, maria,
# Nearest to recorded: records, band, rock, songs, concerts, singing, albums, song,
# Nearest to event: events, place, there, being, periods, about, rather, so,
# Nearest to frac: sum, equation, cos, cdot, x, pi, y, constant,
# Nearest to primarily: and, as, largely, other, most, in, many, of,
# Nearest to question: whether, questions, answer, notion, statement, arguments, argument, agree,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4561 0.4201 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4617 0.4178 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5047 0.4202 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.6079 0.4339 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6577 0.4954 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.4040 0.4722 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5450 0.4182 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.4728 0.4197 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3687 0.4205 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4659 0.4175 sec/batch
# Nearest to called: is, complex, be, a, unique, examples, set, where,
# Nearest to so: be, this, just, if, that, too, not, always,
# Nearest to can: be, or, typically, using, such, cannot, example, specific,
# Nearest to zero: five, two, three, four, six, one, nine, eight,
# Nearest to as: the, to, a, and, their, with, in, most,
# Nearest to years: rate, population, age, male, female, under, birth, infant,
# Nearest to have: this, not, even, or, it, some, that, generally,
# Nearest to new: in, york, began, was, now, by, on, at,
# Nearest to issue: approval, agreed, decision, efforts, policies, campaign, publicly, officials,
# Nearest to assembly: legislative, parliament, elected, cabinet, parliamentary, elections, unicameral, ministers,
# Nearest to paris: france, french, de, charles, sur, le, philippe, iii,
# Nearest to recorded: rock, songs, band, records, albums, album, song, cover,
# Nearest to event: having, chance, events, out, time, but, at, down,
# Nearest to frac: equation, sum, x, cdot, log, pi, y, cos,
# Nearest to primarily: as, most, especially, mainly, largely, more, has, some,
# Nearest to question: questions, idea, that, answer, facts, what, statement, truth,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4533 0.4141 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.4905 0.4101 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
